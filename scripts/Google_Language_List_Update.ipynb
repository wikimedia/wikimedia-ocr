# %%
# !pip install tabulate requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: tabulate in ./venv/lib/python3.13/site-packages (0.9.0)
# Requirement already satisfied: requests in ./venv/lib/python3.13/site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in ./venv/lib/python3.13/site-packages (4.12.3)
# Requirement already satisfied: pandas in ./venv/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.13/site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.13/site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.13/site-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.13/site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: numpy>=1.26.0 in ./venv/lib/python3.13/site-packages (from pandas) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests

url = 'https://cloud.google.com/vision/docs/languages'
headers = {'User-Agent': 'Mozilla/5.0'}  # Some servers require a user-agent header
response = requests.get(url, headers=headers)
html_content = response.content

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_content, 'html.parser')
tables = soup.find_all('table')

# %%
import pandas as pd

dataframes = []
for table in tables:
    # Extract table headers
    headers = [th.get_text(strip=True) for th in table.find_all('th')]

    # Extract table rows
    rows = []
    for tr in table.find_all('tr'):
        cells = tr.find_all(['td', 'th'])
        row = [cell.get_text(strip=True) for cell in cells]
        if row:
            rows.append(row)

    # Adjust rows to match the headers
    if headers:
        adjusted_rows = []
        for row in rows:
            if len(row) < len(headers):
                row.extend([''] * (len(headers) - len(row)))  # Pad with empty strings
            elif len(row) > len(headers):
                row = row[:len(headers)]  # Truncate extra columns
            adjusted_rows.append(row)
        df = pd.DataFrame(adjusted_rows[1:], columns=headers)
    else:
        df = pd.DataFrame(rows)
    dataframes.append(df)

# Output the tables
for i, df in enumerate(dataframes):
    print(f"Table {i+1}")
    print(df.head())  # Print the first few rows
    df.to_csv(f'table_{i+1}.csv', index=False)
# Out:
# Table 1
#      Language Language (English name) languageHintscode Script  \
# 0   Afrikaans               Afrikaans                af   Latn
# 1       shqip                Albanian                sq   Latn
# 2     العربية                  Arabic                ar   Arab
# 3         Հայ                Armenian                hy   Armn
# 4  беларуская              Belarusian                be   Cyrl
#
#              Notes
# 0
# 1
# 2  Modern Standard
# 3
# 4
# Table 2
#                   Language Language (English name) languageHintscode Script  \
# 0                     አማርኛ                 Amharic                am   Ethi
# 1          Αρχαία ελληνικά           Ancient Greek               grc   Grek
# 2                  অসমীয়া                Assamese                as   Beng
# 3               Azərbaycan             Azerbaijani                az   Latn
# 4  Azərbaycan (qədim yazı)             Azerbaijani           az-Cyrl   Cyrl
#
#              Notes
# 0
# 1
# 2
# 3
# 4  Old Orthography
# Table 3
#          Language Language (English name) languageHintscode Script  \
# 0       بهسا اچيه                Acehnese               ace   Latn
# 1             Lwo                  Acholi               ach   Latn
# 2          Dangme                 Adangme               ada   Latn
# 3            Akan                    Akan                ak   Latn
# 4  Anicinâbemowin            Algonquinian               alg   Latn
#
#          Notes
# 0  Latin model
# 1  Latin model
# 2  Latin model
# 3  Latin model
# 4  Latin model
# Table 4
#   Script        Name Support Level
# 0   Beng     Bengali  Experimental
# 1   Cyrl    Cyrillic  Experimental
# 2   Deva  Devanagari  Experimental
# 3   Grek       Greek  Experimental
# 4   Hani     Chinese  Experimental

# %%
from tabulate import tabulate

# Beautify and print each table
for i, df in enumerate(dataframes):
    print(f"\nTable {i+1}:")
    print(tabulate(df, headers='keys', tablefmt='fancy_grid', showindex=False))
# Out:
# Table 1:
# ╒═════════════════════════════╤═══════════════════════════╤═════════════════════╤═══════════╤═════════════════╕
# │ Language                    │ Language (English name)   │ languageHintscode   │ Script    │ Notes           │
# ╞═════════════════════════════╪═══════════════════════════╪═════════════════════╪═══════════╪═════════════════╡
# │ Afrikaans                   │ Afrikaans                 │ af                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ shqip                       │ Albanian                  │ sq                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ العربية                     │ Arabic                    │ ar                  │ Arab      │ Modern Standard │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Հայ                         │ Armenian                  │ hy                  │ Armn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ беларуская                  │ Belarusian                │ be                  │ Cyrl      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ বাংলা                          │ Bengali                   │ bn                  │ Beng      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ български                   │ Bulgarian                 │ bg                  │ Cyrl      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Català                      │ Catalan                   │ ca                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ 普通话                      │ Chinese                   │ zh                  │ Hans/Hant │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Hrvatski                    │ Croatian                  │ hr                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Čeština                     │ Czech                     │ cs                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Dansk                       │ Danish                    │ da                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Nederlands                  │ Dutch                     │ nl                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ English                     │ English                   │ en                  │ Latn      │ American        │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Eesti keel                  │ Estonian                  │ et                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Filipino                    │ Filipino                  │ fil                 │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Suomi                       │ Finnish                   │ fi                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Français                    │ French                    │ fr                  │ Latn      │ European        │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Deutsch                     │ German                    │ de                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Ελληνικά                    │ Greek                     │ el                  │ Grek      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ ગુજરાતી                        │ Gujarati                  │ gu                  │ Gujr      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ עברית                       │ Hebrew                    │ iw                  │ Hebr      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ हिन्दी                         │ Hindi                     │ hi                  │ Deva      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Magyar                      │ Hungarian                 │ hu                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Íslenska                    │ Icelandic                 │ is                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Bahasa Indonesia            │ Indonesian                │ id                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Italiano                    │ Italian                   │ it                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ 日本語                      │ Japanese                  │ ja                  │ Jpan      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ ಕನ್ನಡ                        │ Kannada                   │ kn                  │ Knda      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ ភាសាខ្មែរ                       │ Khmer                     │ km                  │ Khmr      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ 한국어                      │ Korean                    │ ko                  │ Kore      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ ລາວ                         │ Lao                       │ lo                  │ Laoo      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Latviešu                    │ Latvian                   │ lv                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Lietuvių                    │ Lithuanian                │ lt                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Македонски                  │ Macedonian                │ mk                  │ Cyrl      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Bahasa Melayu               │ Malay                     │ ms                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ മലയാളം                        │ Malayalam                 │ ml                  │ Mlym      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ मराठी                         │ Marathi                   │ mr                  │ Deva      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ नेपाली                         │ Nepali                    │ ne                  │ Deva      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Norsk                       │ Norwegian                 │ no                  │ Latn      │ Bokmål          │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ فارسی                       │ Persian                   │ fa                  │ Arab      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Polski                      │ Polish                    │ pl                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Português                   │ Portuguese                │ pt                  │ Latn      │ Brazilian       │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ ਪੰਜਾਬੀ                         │ Punjabi                   │ pa                  │ Guru      │ Gurmukhi        │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Română                      │ Romanian                  │ ro                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Русский                     │ Russian                   │ ru                  │ Cyrl      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Русский (старая орфография) │ Russian                   │ ru-PETR1708         │ Cyrl      │ Old Orthography │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Српски                      │ Serbian                   │ sr                  │ Cyrl      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Српски (латиница)           │ Serbian                   │ sr-Latn             │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Slovenčina                  │ Slovak                    │ sk                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Slovenščina                 │ Slovenian                 │ sl                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Español                     │ Spanish                   │ es                  │ Latn      │ European        │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Svenska                     │ Swedish                   │ sv                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Tagalog                     │ Tagalog                   │ tl                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ தமிழ்                         │ Tamil                     │ ta                  │ Taml      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ తెలుగు                         │ Telugu                    │ te                  │ Telu      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ ไทย                         │ Thai                      │ th                  │ Thai      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Türkçe                      │ Turkish                   │ tr                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Українська                  │ Ukrainian                 │ uk                  │ Cyrl      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Tiếng Việt                  │ Vietnamese                │ vi                  │ Latn      │                 │
# ├─────────────────────────────┼───────────────────────────┼─────────────────────┼───────────┼─────────────────┤
# │ Yiddish                     │ Yiddish                   │ yi                  │ Hebr      │                 │
# ╘═════════════════════════════╧═══════════════════════════╧═════════════════════╧═══════════╧═════════════════╛
#
# Table 2:
# ╒═════════════════════════╤═══════════════════════════╤═════════════════════╤══════════╤═════════════════╕
# │ Language                │ Language (English name)   │ languageHintscode   │ Script   │ Notes           │
# ╞═════════════════════════╪═══════════════════════════╪═════════════════════╪══════════╪═════════════════╡
# │ አማርኛ                    │ Amharic                   │ am                  │ Ethi     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Αρχαία ελληνικά         │ Ancient Greek             │ grc                 │ Grek     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ অসমীয়া                    │ Assamese                  │ as                  │ Beng     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Azərbaycan              │ Azerbaijani               │ az                  │ Latn     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Azərbaycan (qədim yazı) │ Azerbaijani               │ az-Cyrl             │ Cyrl     │ Old Orthography │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Euskara                 │ Basque                    │ eu                  │ Latn     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Bosanski                │ Bosnian                   │ bs                  │ Latn     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ မြန်မာ                     │ Burmese                   │ my                  │ Mymr     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Cebuano                 │ Cebuano                   │ ceb                 │ Latn     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ ᏣᎳᎩ ᎦᏬᏂᎯᏍᏗ              │ Cherokee                  │ chr                 │ Cher     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ dhivehi, dhivehi-bas    │ Dhivehi                   │ dv                  │ Thaa     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ རྫོང་ཁ                    │ Dzonkha                   │ dz                  │ Tibt     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Esperanto               │ Esperanto                 │ eo                  │ Latn     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Galego                  │ Galician                  │ gl                  │ Latn     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ ქართული                 │ Georgian                  │ ka                  │ Geor     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Kreyòl Ayisyen          │ Haitian Creole            │ ht                  │ Latn     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Gaeilge                 │ Irish                     │ ga                  │ Latn     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Jawa                    │ Javanese                  │ jv                  │ Latn     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Қазақ                   │ Kazakh                    │ kk                  │ Cyrl     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Kirghiz                 │ Kirghiz                   │ ky                  │ Cyrl     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Latine                  │ Latin                     │ la                  │ Latn     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Malti                   │ Maltese                   │ mt                  │ Latn     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Монгол                  │ Mongolian                 │ mn                  │ Cyrl     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ ଓଡ଼ିଆ                     │ Oriya                     │ or                  │ Orya     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ پښتو                    │ Pashto                    │ ps                  │ Arab     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ संस्कृतम्                   │ Sanskrit                  │ sa                  │ Deva     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ සිංහල                     │ Sinhala                   │ si                  │ Sinh     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Swahili                 │ Swahili                   │ sw                  │ Latn     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ leššānā Suryāyā         │ Syriac                    │ syr                 │ Syriac   │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ བོད་སྐད་                  │ Tibetan                   │ bo                  │ Tibt     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ ትግርኛ                    │ Tigirinya                 │ ti                  │ Ethi     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ اردو                    │ Urdu                      │ ur                  │ Arab     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ oʻzbekcha               │ Uzbek                     │ uz                  │ Latn     │ Latin           │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ oʻzbekcha               │ Uzbek                     │ uz-Cyrl             │ Cyrl     │ Old Orthography │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ Cymraeg                 │ Welsh                     │ cy                  │ Latn     │                 │
# ├─────────────────────────┼───────────────────────────┼─────────────────────┼──────────┼─────────────────┤
# │ IsiZulu                 │ Zulu                      │ zu                  │ Latn     │                 │
# ╘═════════════════════════╧═══════════════════════════╧═════════════════════╧══════════╧═════════════════╛
#
# Table 3:
# ╒═══════════════════════════════════════════════════╤═════════════════════════════════╤═════════════════════╤═══════════╤════════════════╕
# │ Language                                          │ Language (English name)         │ languageHintscode   │ Script    │ Notes          │
# ╞═══════════════════════════════════════════════════╪═════════════════════════════════╪═════════════════════╪═══════════╪════════════════╡
# │ بهسا اچيه                                         │ Acehnese                        │ ace                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Lwo                                               │ Acholi                          │ ach                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Dangme                                            │ Adangme                         │ ada                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Akan                                              │ Akan                            │ ak                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Anicinâbemowin                                    │ Algonquinian                    │ alg                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Mapudungu                                         │ Araucanian/Mapuche              │ arn                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Asturianu                                         │ Asturian                        │ ast                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Dene                                              │ Athabaskan                      │ ath                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Aymar aru                                         │ Aymara                          │ ay                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Bhāṣa Bali                                        │ Balinese                        │ ban                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Bamanankan                                        │ Bambara                         │ bm                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Narrow Bantu                                      │ Bantu                           │ bnt                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ башҡорт теле                                      │ Bashkir                         │ ba                  │ Cyrl      │ Cyrillic model │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Toba–Batak                                        │ Batak                           │ btk                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Chibemba                                          │ Bemba                           │ bem                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Bikol Naga                                        │ Bikol                           │ bik                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Bichelamar                                        │ Bislama                         │ bi                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Brezhoneg                                         │ Breton                          │ br                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ нохчийн мотт / noxçiyn mott                       │ Chechen                         │ ce                  │ Cyrl      │ Cyrillic model │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ 汉语                                              │ Chinese (Mandarin, Simplified,) │ zh-Hans             │ Hans      │ Chinese model  │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ 漢語                                              │ Chinese (Mandarin, Traditional) │ zh-Hant             │ Hant      │ Chinese model  │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ 普通話                                            │ Chinese (Mandarin, Hong Kong)   │ zh-Hant-HK          │ Hant      │ Chinese model  │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Chahta'                                           │ Choctaw                         │ cho                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Чӑвашла                                           │ Chuvash                         │ cv                  │ Cyrl      │ Cyrillic model │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Cree–Montagnais–Naskapi                           │ Cree                            │ cr                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Mvskoke                                           │ Creek                           │ mus                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ qırımtatar tili, къырымтатар тили                 │ Crimean Tatar                   │ crh                 │ Latn      │ Cyrillic model │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Dakhótiyapi, Dakȟótiyapi                          │ Dakota                          │ dak                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Douala                                            │ Duala                           │ dua                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Ikɔ Efik                                          │ Efik                            │ efi                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ English (British)                                 │ English (British)               │ en-GB               │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Èʋegbe                                            │ Ewe                             │ ee                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ føroyskt mál                                      │ Faroese                         │ fo                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Na Vosa Vakaviti                                  │ Fijian                          │ fj                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ fɔ̀ngbè                                            │ Fon                             │ fon                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Français canadien                                 │ French (Canadian)               │ fr-CA               │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Fulani, Fulah, Peul                               │ Fulah                           │ ff                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Gã                                                │ Ga                              │ gaa                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Luganda                                           │ Ganda                           │ lg                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Basa Gayo                                         │ Gayo                            │ gay                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Kiribati                                          │ Gilbertese                      │ gil                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Gothic                                            │ Gothic                          │ got                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Guaraní                                           │ Guarani                         │ gn                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Harshen/Halshen Hausa هَرْشَن هَوْسَ                    │ Hausa                           │ ha                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ ʻŌlelo Hawaiʻi                                    │ Hawaiian                        │ haw                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Otjiherero                                        │ Herero                          │ hz                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Ilonggo                                           │ Hiligaynon                      │ hil                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Jaku Iban                                         │ Iban                            │ iba                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Asụsụ Igbo                                        │ Igbo                            │ ig                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Ilokano                                           │ Iloko                           │ ilo                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Taqbaylit                                         │ Kabyle                          │ kab                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Jingpho                                           │ Kachin                          │ kac                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Kalaallisut                                       │ Kalaallisut                     │ kl                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Kikamba                                           │ Kamba                           │ kam                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Kanuri                                            │ Kanuri                          │ kr                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Qaraqalpaq tili, Қарақалпақ тили, قاراقالپاق تىلى │ Kara-Kalpak                     │ kaa                 │ Cyrl/Latn │ Cyrillic model │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Ka Ktien Khasi                                    │ Khasi                           │ kha                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Gĩkũyũ                                            │ Kikuyu                          │ ki                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Kinyarwanda                                       │ Kinyarwanda                     │ rw                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ коми кыв                                          │ Komi                            │ kv                  │ Cyrl      │ Cyrillic model │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Kikongo                                           │ Kongo                           │ kg                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Kosraean                                          │ Kosraean                        │ kos                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Oshikwanyama                                      │ Kuanyama                        │ kj                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Ngala                                             │ Lingala                         │ ln                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Plattdütsch, Plattdeutsch, Nedersaksisch          │ Low German                      │ nds                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ siLozi                                            │ Lozi                            │ loz                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Kiluba                                            │ Luba-Katanga                    │ lu                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Dholuo                                            │ Luo                             │ luo                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Madhura, Basa Mathura, بَهاسَ مَدورا                 │ Madurese                        │ mad                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Malagasy                                          │ Malagasy                        │ mg                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Mandinka, لغة مندنكا                              │ Mandingo                        │ man                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Gaelg, Gailck                                     │ Manx                            │ gv                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Te reo Māori                                      │ Maori                           │ mi                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Ebon                                              │ Marshallese                     │ mh                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Mɛnde yia                                         │ Mende                           │ men                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Middle English                                    │ Middle English                  │ enm                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Mittelhochdeutsch                                 │ Middle High German              │ gmh                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Baso Minangkabau, باسو مينڠكاباو                  │ Minangkabau                     │ min                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Kanienʼkéha                                       │ Mohawk                          │ moh                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Nkundu                                            │ Mongo                           │ lol                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Nāhuatl                                           │ Nahuatl                         │ nah                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Diné bizaad                                       │ Navajo                          │ nv                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Ndonga                                            │ Ndonga                          │ ng                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ ko e vagahau Niuē                                 │ Niuean                          │ niu                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Zimbabwe Ndebele                                  │ North Ndebele                   │ nd                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Sesotho sa Leboa                                  │ Northern Sotho                  │ nso                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Chichewa, Chinyanja                               │ Nyanja                          │ ny                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Runyankore                                        │ Nyankole                        │ nyn                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Chitonga                                          │ Nyasa Tonga                     │ tog                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Appolo                                            │ Nzima                           │ nzi                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Occitan, lenga d'òc, provençal                    │ Occitan                         │ oc                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Anishinaabemowin, ᐊᓂᔑᓈᐯᒧᐎᓐ                        │ Ojibwa                          │ oj                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Ænglisc, Englisc, Anglisc                         │ Old English                     │ ang                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Franceis, François, Romanz                        │ Old French                      │ fro                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Diutisk, Althochdeutsch                           │ Old High German                 │ goh                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Dǫnsk tunga                                       │ Old Norse                       │ non                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Occitan ancian                                    │ Old Provencal                   │ pro                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ ирон ӕвзаг                                        │ Ossetic                         │ os                  │ Cyrl      │ Cyrillic model │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Kapampangan                                       │ Pampanga                        │ pam                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Salitan Pangasinan                                │ Pangasinan                      │ pag                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Papiamentu                                        │ Papiamento                      │ pap                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Português (Portugal)                              │ Portuguese (European)           │ pt-PT               │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Kechua / Runa Simi                                │ Quechua                         │ qu                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Rumantsch                                         │ Romansh                         │ rm                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Romani čhib                                       │ Romany                          │ rom                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Ikirundi                                          │ Rundi                           │ rn                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Sakha                                             │ Sakha                           │ sah                 │ Cyrl      │ Cyrillic model │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Gagana faʻa Sāmoa                                 │ Samoan                          │ sm                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ yângâ tî sängö                                    │ Sango                           │ sg                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ (Braid) Scots, Lallans, Doric                     │ Scots                           │ sco                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Gàidhlig                                          │ Scottish Gaelic                 │ gd                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ chiShona                                          │ Shona                           │ sn                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Songhay                                           │ Songhai                         │ son                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Sesotho                                           │ Southern Sotho                  │ st                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Español (Latinoamérica)                           │ Spanish (Latin American)        │ es-419              │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ ᮘᮞ ᮞᮥᮔ᮪ᮓ , Basa Sunda                               │ Sundanese                       │ su                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ siSwati                                           │ Swati                           │ ss                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Reo Tahiti                                        │ Tahitian                        │ ty                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ тоҷикӣ                                            │ Tajik                           │ tg                  │ Cyrl      │ Cyrillic model │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ татар теле                                        │ Tatar                           │ tt                  │ Cyrl/Latn │ Cyrillic model │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ KʌThemnɛ                                          │ Temne                           │ tem                 │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ lea faka-Tonga                                    │ Tongan                          │ to                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Xitsonga                                          │ Tsonga                          │ ts                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Setswana                                          │ Tswana                          │ tn                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Türkmençe                                         │ Turkmen                         │ tk                  │ Latn      │ Cyrillic model │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ удмурт кыл                                        │ Udmurt                          │ udm                 │ Cyrl      │ Cyrillic model │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Tshivenḓa                                         │ Venda                           │ ve                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Vod                                               │ Votic                           │ vot                 │ Cyrl/Latn │ Cyrillic model │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Frysk                                             │ Western Frisian                 │ fy                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Wolof                                             │ Wolof                           │ wo                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ isiXhosa                                          │ Xhosa                           │ xh                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Èdè Yorùbá                                        │ Yoruba                          │ yo                  │ Latn      │ Latin model    │
# ├───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼────────────────┤
# │ Diidxazá                                          │ Zapotec                         │ zap                 │ Latn      │ Latin model    │
# ╘═══════════════════════════════════════════════════╧═════════════════════════════════╧═════════════════════╧═══════════╧════════════════╛
#
# Table 4:
# ╒══════════╤════════════╤═════════════════╕
# │ Script   │ Name       │ Support Level   │
# ╞══════════╪════════════╪═════════════════╡
# │ Beng     │ Bengali    │ Experimental    │
# ├──────────┼────────────┼─────────────────┤
# │ Cyrl     │ Cyrillic   │ Experimental    │
# ├──────────┼────────────┼─────────────────┤
# │ Deva     │ Devanagari │ Experimental    │
# ├──────────┼────────────┼─────────────────┤
# │ Grek     │ Greek      │ Experimental    │
# ├──────────┼────────────┼─────────────────┤
# │ Hani     │ Chinese    │ Experimental    │
# ├──────────┼────────────┼─────────────────┤
# │ Jpan     │ Japanese   │ Supported       │
# ├──────────┼────────────┼─────────────────┤
# │ Kore     │ Korean     │ Supported       │
# ├──────────┼────────────┼─────────────────┤
# │ Latn     │ Latin      │ Supported       │
# ├──────────┼────────────┼─────────────────┤
# │ vi       │ Vietnamese │ Experimental    │
# ╘══════════╧════════════╧═════════════════╛

# %%
import pandas as pd

# Select tables with indexes 0, 1, and 2
tables_to_merge = [dataframes[0], dataframes[1], dataframes[2]]

# Standardize column names across all selected tables
for i, table in enumerate(tables_to_merge):
    tables_to_merge[i].columns = ['Language', 'Language (English name)', 'languageHintscode', 'Script', 'Notes']

# Add a 'Mapping' column to each DataFrame
for i, table in enumerate(tables_to_merge):
    mapping_value = 'Mapped' if i == 2 else ''
    tables_to_merge[i]['Mapping'] = mapping_value

# Merge tables
merged_table = pd.concat(tables_to_merge, ignore_index=True)

# Print the merged table
print("\nMerged Table:")
print(tabulate(merged_table, headers='keys', tablefmt='fancy_grid', showindex=True))
# Out:
# Merged Table:
# ╒═════╤═══════════════════════════════════════════════════╤═════════════════════════════════╤═════════════════════╤═══════════╤═════════════════╤═══════════╕
# │     │ Language                                          │ Language (English name)         │ languageHintscode   │ Script    │ Notes           │ Mapping   │
# ╞═════╪═══════════════════════════════════════════════════╪═════════════════════════════════╪═════════════════════╪═══════════╪═════════════════╪═══════════╡
# │   0 │ Afrikaans                                         │ Afrikaans                       │ af                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │   1 │ shqip                                             │ Albanian                        │ sq                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │   2 │ العربية                                           │ Arabic                          │ ar                  │ Arab      │ Modern Standard │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │   3 │ Հայ                                               │ Armenian                        │ hy                  │ Armn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │   4 │ беларуская                                        │ Belarusian                      │ be                  │ Cyrl      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │   5 │ বাংলা                                                │ Bengali                         │ bn                  │ Beng      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │   6 │ български                                         │ Bulgarian                       │ bg                  │ Cyrl      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │   7 │ Català                                            │ Catalan                         │ ca                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │   8 │ 普通话                                            │ Chinese                         │ zh                  │ Hans/Hant │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │   9 │ Hrvatski                                          │ Croatian                        │ hr                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  10 │ Čeština                                           │ Czech                           │ cs                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  11 │ Dansk                                             │ Danish                          │ da                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  12 │ Nederlands                                        │ Dutch                           │ nl                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  13 │ English                                           │ English                         │ en                  │ Latn      │ American        │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  14 │ Eesti keel                                        │ Estonian                        │ et                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  15 │ Filipino                                          │ Filipino                        │ fil                 │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  16 │ Suomi                                             │ Finnish                         │ fi                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  17 │ Français                                          │ French                          │ fr                  │ Latn      │ European        │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  18 │ Deutsch                                           │ German                          │ de                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  19 │ Ελληνικά                                          │ Greek                           │ el                  │ Grek      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  20 │ ગુજરાતી                                              │ Gujarati                        │ gu                  │ Gujr      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  21 │ עברית                                             │ Hebrew                          │ iw                  │ Hebr      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  22 │ हिन्दी                                               │ Hindi                           │ hi                  │ Deva      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  23 │ Magyar                                            │ Hungarian                       │ hu                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  24 │ Íslenska                                          │ Icelandic                       │ is                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  25 │ Bahasa Indonesia                                  │ Indonesian                      │ id                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  26 │ Italiano                                          │ Italian                         │ it                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  27 │ 日本語                                            │ Japanese                        │ ja                  │ Jpan      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  28 │ ಕನ್ನಡ                                              │ Kannada                         │ kn                  │ Knda      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  29 │ ភាសាខ្មែរ                                             │ Khmer                           │ km                  │ Khmr      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  30 │ 한국어                                            │ Korean                          │ ko                  │ Kore      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  31 │ ລາວ                                               │ Lao                             │ lo                  │ Laoo      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  32 │ Latviešu                                          │ Latvian                         │ lv                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  33 │ Lietuvių                                          │ Lithuanian                      │ lt                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  34 │ Македонски                                        │ Macedonian                      │ mk                  │ Cyrl      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  35 │ Bahasa Melayu                                     │ Malay                           │ ms                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  36 │ മലയാളം                                              │ Malayalam                       │ ml                  │ Mlym      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  37 │ मराठी                                               │ Marathi                         │ mr                  │ Deva      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  38 │ नेपाली                                               │ Nepali                          │ ne                  │ Deva      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  39 │ Norsk                                             │ Norwegian                       │ no                  │ Latn      │ Bokmål          │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  40 │ فارسی                                             │ Persian                         │ fa                  │ Arab      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  41 │ Polski                                            │ Polish                          │ pl                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  42 │ Português                                         │ Portuguese                      │ pt                  │ Latn      │ Brazilian       │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  43 │ ਪੰਜਾਬੀ                                               │ Punjabi                         │ pa                  │ Guru      │ Gurmukhi        │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  44 │ Română                                            │ Romanian                        │ ro                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  45 │ Русский                                           │ Russian                         │ ru                  │ Cyrl      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  46 │ Русский (старая орфография)                       │ Russian                         │ ru-PETR1708         │ Cyrl      │ Old Orthography │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  47 │ Српски                                            │ Serbian                         │ sr                  │ Cyrl      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  48 │ Српски (латиница)                                 │ Serbian                         │ sr-Latn             │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  49 │ Slovenčina                                        │ Slovak                          │ sk                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  50 │ Slovenščina                                       │ Slovenian                       │ sl                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  51 │ Español                                           │ Spanish                         │ es                  │ Latn      │ European        │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  52 │ Svenska                                           │ Swedish                         │ sv                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  53 │ Tagalog                                           │ Tagalog                         │ tl                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  54 │ தமிழ்                                               │ Tamil                           │ ta                  │ Taml      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  55 │ తెలుగు                                               │ Telugu                          │ te                  │ Telu      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  56 │ ไทย                                               │ Thai                            │ th                  │ Thai      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  57 │ Türkçe                                            │ Turkish                         │ tr                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  58 │ Українська                                        │ Ukrainian                       │ uk                  │ Cyrl      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  59 │ Tiếng Việt                                        │ Vietnamese                      │ vi                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  60 │ Yiddish                                           │ Yiddish                         │ yi                  │ Hebr      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  61 │ አማርኛ                                              │ Amharic                         │ am                  │ Ethi      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  62 │ Αρχαία ελληνικά                                   │ Ancient Greek                   │ grc                 │ Grek      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  63 │ অসমীয়া                                              │ Assamese                        │ as                  │ Beng      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  64 │ Azərbaycan                                        │ Azerbaijani                     │ az                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  65 │ Azərbaycan (qədim yazı)                           │ Azerbaijani                     │ az-Cyrl             │ Cyrl      │ Old Orthography │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  66 │ Euskara                                           │ Basque                          │ eu                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  67 │ Bosanski                                          │ Bosnian                         │ bs                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  68 │ မြန်မာ                                               │ Burmese                         │ my                  │ Mymr      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  69 │ Cebuano                                           │ Cebuano                         │ ceb                 │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  70 │ ᏣᎳᎩ ᎦᏬᏂᎯᏍᏗ                                        │ Cherokee                        │ chr                 │ Cher      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  71 │ dhivehi, dhivehi-bas                              │ Dhivehi                         │ dv                  │ Thaa      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  72 │ རྫོང་ཁ                                              │ Dzonkha                         │ dz                  │ Tibt      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  73 │ Esperanto                                         │ Esperanto                       │ eo                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  74 │ Galego                                            │ Galician                        │ gl                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  75 │ ქართული                                           │ Georgian                        │ ka                  │ Geor      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  76 │ Kreyòl Ayisyen                                    │ Haitian Creole                  │ ht                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  77 │ Gaeilge                                           │ Irish                           │ ga                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  78 │ Jawa                                              │ Javanese                        │ jv                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  79 │ Қазақ                                             │ Kazakh                          │ kk                  │ Cyrl      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  80 │ Kirghiz                                           │ Kirghiz                         │ ky                  │ Cyrl      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  81 │ Latine                                            │ Latin                           │ la                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  82 │ Malti                                             │ Maltese                         │ mt                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  83 │ Монгол                                            │ Mongolian                       │ mn                  │ Cyrl      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  84 │ ଓଡ଼ିଆ                                               │ Oriya                           │ or                  │ Orya      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  85 │ پښتو                                              │ Pashto                          │ ps                  │ Arab      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  86 │ संस्कृतम्                                             │ Sanskrit                        │ sa                  │ Deva      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  87 │ සිංහල                                               │ Sinhala                         │ si                  │ Sinh      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  88 │ Swahili                                           │ Swahili                         │ sw                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  89 │ leššānā Suryāyā                                   │ Syriac                          │ syr                 │ Syriac    │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  90 │ བོད་སྐད་                                            │ Tibetan                         │ bo                  │ Tibt      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  91 │ ትግርኛ                                              │ Tigirinya                       │ ti                  │ Ethi      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  92 │ اردو                                              │ Urdu                            │ ur                  │ Arab      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  93 │ oʻzbekcha                                         │ Uzbek                           │ uz                  │ Latn      │ Latin           │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  94 │ oʻzbekcha                                         │ Uzbek                           │ uz-Cyrl             │ Cyrl      │ Old Orthography │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  95 │ Cymraeg                                           │ Welsh                           │ cy                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  96 │ IsiZulu                                           │ Zulu                            │ zu                  │ Latn      │                 │           │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  97 │ بهسا اچيه                                         │ Acehnese                        │ ace                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  98 │ Lwo                                               │ Acholi                          │ ach                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │  99 │ Dangme                                            │ Adangme                         │ ada                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 100 │ Akan                                              │ Akan                            │ ak                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 101 │ Anicinâbemowin                                    │ Algonquinian                    │ alg                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 102 │ Mapudungu                                         │ Araucanian/Mapuche              │ arn                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 103 │ Asturianu                                         │ Asturian                        │ ast                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 104 │ Dene                                              │ Athabaskan                      │ ath                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 105 │ Aymar aru                                         │ Aymara                          │ ay                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 106 │ Bhāṣa Bali                                        │ Balinese                        │ ban                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 107 │ Bamanankan                                        │ Bambara                         │ bm                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 108 │ Narrow Bantu                                      │ Bantu                           │ bnt                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 109 │ башҡорт теле                                      │ Bashkir                         │ ba                  │ Cyrl      │ Cyrillic model  │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 110 │ Toba–Batak                                        │ Batak                           │ btk                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 111 │ Chibemba                                          │ Bemba                           │ bem                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 112 │ Bikol Naga                                        │ Bikol                           │ bik                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 113 │ Bichelamar                                        │ Bislama                         │ bi                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 114 │ Brezhoneg                                         │ Breton                          │ br                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 115 │ нохчийн мотт / noxçiyn mott                       │ Chechen                         │ ce                  │ Cyrl      │ Cyrillic model  │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 116 │ 汉语                                              │ Chinese (Mandarin, Simplified,) │ zh-Hans             │ Hans      │ Chinese model   │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 117 │ 漢語                                              │ Chinese (Mandarin, Traditional) │ zh-Hant             │ Hant      │ Chinese model   │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 118 │ 普通話                                            │ Chinese (Mandarin, Hong Kong)   │ zh-Hant-HK          │ Hant      │ Chinese model   │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 119 │ Chahta'                                           │ Choctaw                         │ cho                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 120 │ Чӑвашла                                           │ Chuvash                         │ cv                  │ Cyrl      │ Cyrillic model  │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 121 │ Cree–Montagnais–Naskapi                           │ Cree                            │ cr                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 122 │ Mvskoke                                           │ Creek                           │ mus                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 123 │ qırımtatar tili, къырымтатар тили                 │ Crimean Tatar                   │ crh                 │ Latn      │ Cyrillic model  │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 124 │ Dakhótiyapi, Dakȟótiyapi                          │ Dakota                          │ dak                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 125 │ Douala                                            │ Duala                           │ dua                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 126 │ Ikɔ Efik                                          │ Efik                            │ efi                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 127 │ English (British)                                 │ English (British)               │ en-GB               │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 128 │ Èʋegbe                                            │ Ewe                             │ ee                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 129 │ føroyskt mál                                      │ Faroese                         │ fo                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 130 │ Na Vosa Vakaviti                                  │ Fijian                          │ fj                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 131 │ fɔ̀ngbè                                            │ Fon                             │ fon                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 132 │ Français canadien                                 │ French (Canadian)               │ fr-CA               │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 133 │ Fulani, Fulah, Peul                               │ Fulah                           │ ff                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 134 │ Gã                                                │ Ga                              │ gaa                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 135 │ Luganda                                           │ Ganda                           │ lg                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 136 │ Basa Gayo                                         │ Gayo                            │ gay                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 137 │ Kiribati                                          │ Gilbertese                      │ gil                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 138 │ Gothic                                            │ Gothic                          │ got                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 139 │ Guaraní                                           │ Guarani                         │ gn                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 140 │ Harshen/Halshen Hausa هَرْشَن هَوْسَ                    │ Hausa                           │ ha                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 141 │ ʻŌlelo Hawaiʻi                                    │ Hawaiian                        │ haw                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 142 │ Otjiherero                                        │ Herero                          │ hz                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 143 │ Ilonggo                                           │ Hiligaynon                      │ hil                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 144 │ Jaku Iban                                         │ Iban                            │ iba                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 145 │ Asụsụ Igbo                                        │ Igbo                            │ ig                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 146 │ Ilokano                                           │ Iloko                           │ ilo                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 147 │ Taqbaylit                                         │ Kabyle                          │ kab                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 148 │ Jingpho                                           │ Kachin                          │ kac                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 149 │ Kalaallisut                                       │ Kalaallisut                     │ kl                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# ...
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 180 │ ko e vagahau Niuē                                 │ Niuean                          │ niu                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 181 │ Zimbabwe Ndebele                                  │ North Ndebele                   │ nd                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 182 │ Sesotho sa Leboa                                  │ Northern Sotho                  │ nso                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 183 │ Chichewa, Chinyanja                               │ Nyanja                          │ ny                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 184 │ Runyankore                                        │ Nyankole                        │ nyn                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 185 │ Chitonga                                          │ Nyasa Tonga                     │ tog                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 186 │ Appolo                                            │ Nzima                           │ nzi                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 187 │ Occitan, lenga d'òc, provençal                    │ Occitan                         │ oc                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 188 │ Anishinaabemowin, ᐊᓂᔑᓈᐯᒧᐎᓐ                        │ Ojibwa                          │ oj                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 189 │ Ænglisc, Englisc, Anglisc                         │ Old English                     │ ang                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 190 │ Franceis, François, Romanz                        │ Old French                      │ fro                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 191 │ Diutisk, Althochdeutsch                           │ Old High German                 │ goh                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 192 │ Dǫnsk tunga                                       │ Old Norse                       │ non                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 193 │ Occitan ancian                                    │ Old Provencal                   │ pro                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 194 │ ирон ӕвзаг                                        │ Ossetic                         │ os                  │ Cyrl      │ Cyrillic model  │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 195 │ Kapampangan                                       │ Pampanga                        │ pam                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 196 │ Salitan Pangasinan                                │ Pangasinan                      │ pag                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 197 │ Papiamentu                                        │ Papiamento                      │ pap                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 198 │ Português (Portugal)                              │ Portuguese (European)           │ pt-PT               │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 199 │ Kechua / Runa Simi                                │ Quechua                         │ qu                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 200 │ Rumantsch                                         │ Romansh                         │ rm                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 201 │ Romani čhib                                       │ Romany                          │ rom                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 202 │ Ikirundi                                          │ Rundi                           │ rn                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 203 │ Sakha                                             │ Sakha                           │ sah                 │ Cyrl      │ Cyrillic model  │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 204 │ Gagana faʻa Sāmoa                                 │ Samoan                          │ sm                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 205 │ yângâ tî sängö                                    │ Sango                           │ sg                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 206 │ (Braid) Scots, Lallans, Doric                     │ Scots                           │ sco                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 207 │ Gàidhlig                                          │ Scottish Gaelic                 │ gd                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 208 │ chiShona                                          │ Shona                           │ sn                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 209 │ Songhay                                           │ Songhai                         │ son                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 210 │ Sesotho                                           │ Southern Sotho                  │ st                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 211 │ Español (Latinoamérica)                           │ Spanish (Latin American)        │ es-419              │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 212 │ ᮘᮞ ᮞᮥᮔ᮪ᮓ , Basa Sunda                               │ Sundanese                       │ su                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 213 │ siSwati                                           │ Swati                           │ ss                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 214 │ Reo Tahiti                                        │ Tahitian                        │ ty                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 215 │ тоҷикӣ                                            │ Tajik                           │ tg                  │ Cyrl      │ Cyrillic model  │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 216 │ татар теле                                        │ Tatar                           │ tt                  │ Cyrl/Latn │ Cyrillic model  │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 217 │ KʌThemnɛ                                          │ Temne                           │ tem                 │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 218 │ lea faka-Tonga                                    │ Tongan                          │ to                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 219 │ Xitsonga                                          │ Tsonga                          │ ts                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 220 │ Setswana                                          │ Tswana                          │ tn                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 221 │ Türkmençe                                         │ Turkmen                         │ tk                  │ Latn      │ Cyrillic model  │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 222 │ удмурт кыл                                        │ Udmurt                          │ udm                 │ Cyrl      │ Cyrillic model  │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 223 │ Tshivenḓa                                         │ Venda                           │ ve                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 224 │ Vod                                               │ Votic                           │ vot                 │ Cyrl/Latn │ Cyrillic model  │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 225 │ Frysk                                             │ Western Frisian                 │ fy                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 226 │ Wolof                                             │ Wolof                           │ wo                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 227 │ isiXhosa                                          │ Xhosa                           │ xh                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 228 │ Èdè Yorùbá                                        │ Yoruba                          │ yo                  │ Latn      │ Latin model     │ Mapped    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┤
# │ 229 │ Diidxazá                                          │ Zapotec                         │ zap                 │ Latn      │ Latin model     │ Mapped    │
# ╘═════╧═══════════════════════════════════════════════════╧═════════════════════════════════╧═════════════════════╧═══════════╧═════════════════╧═══════════╛

# %%
# # Add a new column 'Support Level' to the merged table with default value 'N/A'
# merged_table['Support Level'] = 'N/A'

# # Table with index 3
# table_3 = dataframes[3]

# # Iterate over the merged table and update 'Support Level' based on matching Script values
# for index, row in merged_table.iterrows():
#     if row['Script'] in table_3['Script'].values:
#         merged_table.at[index, 'Support Level'] = 'Supports Handwriting'

# # Print the updated merged table
# print("\nUpdated Merged Table:")
# print(tabulate(merged_table, headers='keys', tablefmt='fancy_grid', showindex=True))

# Add a new column "Support Level" to the merged table, initialized with empty strings
merged_table['Support Level'] = ''

# Create a mapping from the table with index 3 (Script -> Support Level)
script_support_mapping = dict(zip(dataframes[3]['Script'], dataframes[3]['Support Level']))

# Populate the "Support Level" column in the merged table
merged_table['Support Level'] = merged_table['Script'].map(script_support_mapping).fillna('')

# Print the updated merged table
print("\nUpdated Merged Table with Support Level:")
print(tabulate(merged_table, headers='keys', tablefmt='fancy_grid', showindex=True))
# Out:
# Updated Merged Table with Support Level:
# ╒═════╤═══════════════════════════════════════════════════╤═════════════════════════════════╤═════════════════════╤═══════════╤═════════════════╤═══════════╤═════════════════╕
# │     │ Language                                          │ Language (English name)         │ languageHintscode   │ Script    │ Notes           │ Mapping   │ Support Level   │
# ╞═════╪═══════════════════════════════════════════════════╪═════════════════════════════════╪═════════════════════╪═══════════╪═════════════════╪═══════════╪═════════════════╡
# │   0 │ Afrikaans                                         │ Afrikaans                       │ af                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │   1 │ shqip                                             │ Albanian                        │ sq                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │   2 │ العربية                                           │ Arabic                          │ ar                  │ Arab      │ Modern Standard │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │   3 │ Հայ                                               │ Armenian                        │ hy                  │ Armn      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │   4 │ беларуская                                        │ Belarusian                      │ be                  │ Cyrl      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │   5 │ বাংলা                                                │ Bengali                         │ bn                  │ Beng      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │   6 │ български                                         │ Bulgarian                       │ bg                  │ Cyrl      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │   7 │ Català                                            │ Catalan                         │ ca                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │   8 │ 普通话                                            │ Chinese                         │ zh                  │ Hans/Hant │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │   9 │ Hrvatski                                          │ Croatian                        │ hr                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  10 │ Čeština                                           │ Czech                           │ cs                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  11 │ Dansk                                             │ Danish                          │ da                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  12 │ Nederlands                                        │ Dutch                           │ nl                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  13 │ English                                           │ English                         │ en                  │ Latn      │ American        │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  14 │ Eesti keel                                        │ Estonian                        │ et                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  15 │ Filipino                                          │ Filipino                        │ fil                 │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  16 │ Suomi                                             │ Finnish                         │ fi                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  17 │ Français                                          │ French                          │ fr                  │ Latn      │ European        │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  18 │ Deutsch                                           │ German                          │ de                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  19 │ Ελληνικά                                          │ Greek                           │ el                  │ Grek      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  20 │ ગુજરાતી                                              │ Gujarati                        │ gu                  │ Gujr      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  21 │ עברית                                             │ Hebrew                          │ iw                  │ Hebr      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  22 │ हिन्दी                                               │ Hindi                           │ hi                  │ Deva      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  23 │ Magyar                                            │ Hungarian                       │ hu                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  24 │ Íslenska                                          │ Icelandic                       │ is                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  25 │ Bahasa Indonesia                                  │ Indonesian                      │ id                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  26 │ Italiano                                          │ Italian                         │ it                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  27 │ 日本語                                            │ Japanese                        │ ja                  │ Jpan      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  28 │ ಕನ್ನಡ                                              │ Kannada                         │ kn                  │ Knda      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  29 │ ភាសាខ្មែរ                                             │ Khmer                           │ km                  │ Khmr      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  30 │ 한국어                                            │ Korean                          │ ko                  │ Kore      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  31 │ ລາວ                                               │ Lao                             │ lo                  │ Laoo      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  32 │ Latviešu                                          │ Latvian                         │ lv                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  33 │ Lietuvių                                          │ Lithuanian                      │ lt                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  34 │ Македонски                                        │ Macedonian                      │ mk                  │ Cyrl      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  35 │ Bahasa Melayu                                     │ Malay                           │ ms                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  36 │ മലയാളം                                              │ Malayalam                       │ ml                  │ Mlym      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  37 │ मराठी                                               │ Marathi                         │ mr                  │ Deva      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  38 │ नेपाली                                               │ Nepali                          │ ne                  │ Deva      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  39 │ Norsk                                             │ Norwegian                       │ no                  │ Latn      │ Bokmål          │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  40 │ فارسی                                             │ Persian                         │ fa                  │ Arab      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  41 │ Polski                                            │ Polish                          │ pl                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  42 │ Português                                         │ Portuguese                      │ pt                  │ Latn      │ Brazilian       │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  43 │ ਪੰਜਾਬੀ                                               │ Punjabi                         │ pa                  │ Guru      │ Gurmukhi        │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  44 │ Română                                            │ Romanian                        │ ro                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  45 │ Русский                                           │ Russian                         │ ru                  │ Cyrl      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  46 │ Русский (старая орфография)                       │ Russian                         │ ru-PETR1708         │ Cyrl      │ Old Orthography │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  47 │ Српски                                            │ Serbian                         │ sr                  │ Cyrl      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  48 │ Српски (латиница)                                 │ Serbian                         │ sr-Latn             │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  49 │ Slovenčina                                        │ Slovak                          │ sk                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  50 │ Slovenščina                                       │ Slovenian                       │ sl                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  51 │ Español                                           │ Spanish                         │ es                  │ Latn      │ European        │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  52 │ Svenska                                           │ Swedish                         │ sv                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  53 │ Tagalog                                           │ Tagalog                         │ tl                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  54 │ தமிழ்                                               │ Tamil                           │ ta                  │ Taml      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  55 │ తెలుగు                                               │ Telugu                          │ te                  │ Telu      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  56 │ ไทย                                               │ Thai                            │ th                  │ Thai      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  57 │ Türkçe                                            │ Turkish                         │ tr                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  58 │ Українська                                        │ Ukrainian                       │ uk                  │ Cyrl      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  59 │ Tiếng Việt                                        │ Vietnamese                      │ vi                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  60 │ Yiddish                                           │ Yiddish                         │ yi                  │ Hebr      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  61 │ አማርኛ                                              │ Amharic                         │ am                  │ Ethi      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  62 │ Αρχαία ελληνικά                                   │ Ancient Greek                   │ grc                 │ Grek      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  63 │ অসমীয়া                                              │ Assamese                        │ as                  │ Beng      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  64 │ Azərbaycan                                        │ Azerbaijani                     │ az                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  65 │ Azərbaycan (qədim yazı)                           │ Azerbaijani                     │ az-Cyrl             │ Cyrl      │ Old Orthography │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  66 │ Euskara                                           │ Basque                          │ eu                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  67 │ Bosanski                                          │ Bosnian                         │ bs                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  68 │ မြန်မာ                                               │ Burmese                         │ my                  │ Mymr      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  69 │ Cebuano                                           │ Cebuano                         │ ceb                 │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  70 │ ᏣᎳᎩ ᎦᏬᏂᎯᏍᏗ                                        │ Cherokee                        │ chr                 │ Cher      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  71 │ dhivehi, dhivehi-bas                              │ Dhivehi                         │ dv                  │ Thaa      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  72 │ རྫོང་ཁ                                              │ Dzonkha                         │ dz                  │ Tibt      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  73 │ Esperanto                                         │ Esperanto                       │ eo                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  74 │ Galego                                            │ Galician                        │ gl                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  75 │ ქართული                                           │ Georgian                        │ ka                  │ Geor      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  76 │ Kreyòl Ayisyen                                    │ Haitian Creole                  │ ht                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  77 │ Gaeilge                                           │ Irish                           │ ga                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  78 │ Jawa                                              │ Javanese                        │ jv                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  79 │ Қазақ                                             │ Kazakh                          │ kk                  │ Cyrl      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  80 │ Kirghiz                                           │ Kirghiz                         │ ky                  │ Cyrl      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  81 │ Latine                                            │ Latin                           │ la                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  82 │ Malti                                             │ Maltese                         │ mt                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  83 │ Монгол                                            │ Mongolian                       │ mn                  │ Cyrl      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  84 │ ଓଡ଼ିଆ                                               │ Oriya                           │ or                  │ Orya      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  85 │ پښتو                                              │ Pashto                          │ ps                  │ Arab      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  86 │ संस्कृतम्                                             │ Sanskrit                        │ sa                  │ Deva      │                 │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  87 │ සිංහල                                               │ Sinhala                         │ si                  │ Sinh      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  88 │ Swahili                                           │ Swahili                         │ sw                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  89 │ leššānā Suryāyā                                   │ Syriac                          │ syr                 │ Syriac    │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  90 │ བོད་སྐད་                                            │ Tibetan                         │ bo                  │ Tibt      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  91 │ ትግርኛ                                              │ Tigirinya                       │ ti                  │ Ethi      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  92 │ اردو                                              │ Urdu                            │ ur                  │ Arab      │                 │           │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  93 │ oʻzbekcha                                         │ Uzbek                           │ uz                  │ Latn      │ Latin           │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  94 │ oʻzbekcha                                         │ Uzbek                           │ uz-Cyrl             │ Cyrl      │ Old Orthography │           │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  95 │ Cymraeg                                           │ Welsh                           │ cy                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  96 │ IsiZulu                                           │ Zulu                            │ zu                  │ Latn      │                 │           │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  97 │ بهسا اچيه                                         │ Acehnese                        │ ace                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  98 │ Lwo                                               │ Acholi                          │ ach                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │  99 │ Dangme                                            │ Adangme                         │ ada                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 100 │ Akan                                              │ Akan                            │ ak                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 101 │ Anicinâbemowin                                    │ Algonquinian                    │ alg                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 102 │ Mapudungu                                         │ Araucanian/Mapuche              │ arn                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 103 │ Asturianu                                         │ Asturian                        │ ast                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 104 │ Dene                                              │ Athabaskan                      │ ath                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 105 │ Aymar aru                                         │ Aymara                          │ ay                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 106 │ Bhāṣa Bali                                        │ Balinese                        │ ban                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 107 │ Bamanankan                                        │ Bambara                         │ bm                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 108 │ Narrow Bantu                                      │ Bantu                           │ bnt                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 109 │ башҡорт теле                                      │ Bashkir                         │ ba                  │ Cyrl      │ Cyrillic model  │ Mapped    │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 110 │ Toba–Batak                                        │ Batak                           │ btk                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 111 │ Chibemba                                          │ Bemba                           │ bem                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 112 │ Bikol Naga                                        │ Bikol                           │ bik                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 113 │ Bichelamar                                        │ Bislama                         │ bi                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 114 │ Brezhoneg                                         │ Breton                          │ br                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 115 │ нохчийн мотт / noxçiyn mott                       │ Chechen                         │ ce                  │ Cyrl      │ Cyrillic model  │ Mapped    │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 116 │ 汉语                                              │ Chinese (Mandarin, Simplified,) │ zh-Hans             │ Hans      │ Chinese model   │ Mapped    │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 117 │ 漢語                                              │ Chinese (Mandarin, Traditional) │ zh-Hant             │ Hant      │ Chinese model   │ Mapped    │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 118 │ 普通話                                            │ Chinese (Mandarin, Hong Kong)   │ zh-Hant-HK          │ Hant      │ Chinese model   │ Mapped    │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 119 │ Chahta'                                           │ Choctaw                         │ cho                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 120 │ Чӑвашла                                           │ Chuvash                         │ cv                  │ Cyrl      │ Cyrillic model  │ Mapped    │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 121 │ Cree–Montagnais–Naskapi                           │ Cree                            │ cr                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 122 │ Mvskoke                                           │ Creek                           │ mus                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 123 │ qırımtatar tili, къырымтатар тили                 │ Crimean Tatar                   │ crh                 │ Latn      │ Cyrillic model  │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 124 │ Dakhótiyapi, Dakȟótiyapi                          │ Dakota                          │ dak                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 125 │ Douala                                            │ Duala                           │ dua                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 126 │ Ikɔ Efik                                          │ Efik                            │ efi                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 127 │ English (British)                                 │ English (British)               │ en-GB               │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 128 │ Èʋegbe                                            │ Ewe                             │ ee                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 129 │ føroyskt mál                                      │ Faroese                         │ fo                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 130 │ Na Vosa Vakaviti                                  │ Fijian                          │ fj                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 131 │ fɔ̀ngbè                                            │ Fon                             │ fon                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 132 │ Français canadien                                 │ French (Canadian)               │ fr-CA               │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 133 │ Fulani, Fulah, Peul                               │ Fulah                           │ ff                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 134 │ Gã                                                │ Ga                              │ gaa                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ...
# │ 185 │ Chitonga                                          │ Nyasa Tonga                     │ tog                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 186 │ Appolo                                            │ Nzima                           │ nzi                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 187 │ Occitan, lenga d'òc, provençal                    │ Occitan                         │ oc                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 188 │ Anishinaabemowin, ᐊᓂᔑᓈᐯᒧᐎᓐ                        │ Ojibwa                          │ oj                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 189 │ Ænglisc, Englisc, Anglisc                         │ Old English                     │ ang                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 190 │ Franceis, François, Romanz                        │ Old French                      │ fro                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 191 │ Diutisk, Althochdeutsch                           │ Old High German                 │ goh                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 192 │ Dǫnsk tunga                                       │ Old Norse                       │ non                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 193 │ Occitan ancian                                    │ Old Provencal                   │ pro                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 194 │ ирон ӕвзаг                                        │ Ossetic                         │ os                  │ Cyrl      │ Cyrillic model  │ Mapped    │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 195 │ Kapampangan                                       │ Pampanga                        │ pam                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 196 │ Salitan Pangasinan                                │ Pangasinan                      │ pag                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 197 │ Papiamentu                                        │ Papiamento                      │ pap                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 198 │ Português (Portugal)                              │ Portuguese (European)           │ pt-PT               │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 199 │ Kechua / Runa Simi                                │ Quechua                         │ qu                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 200 │ Rumantsch                                         │ Romansh                         │ rm                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 201 │ Romani čhib                                       │ Romany                          │ rom                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 202 │ Ikirundi                                          │ Rundi                           │ rn                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 203 │ Sakha                                             │ Sakha                           │ sah                 │ Cyrl      │ Cyrillic model  │ Mapped    │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 204 │ Gagana faʻa Sāmoa                                 │ Samoan                          │ sm                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 205 │ yângâ tî sängö                                    │ Sango                           │ sg                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 206 │ (Braid) Scots, Lallans, Doric                     │ Scots                           │ sco                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 207 │ Gàidhlig                                          │ Scottish Gaelic                 │ gd                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 208 │ chiShona                                          │ Shona                           │ sn                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 209 │ Songhay                                           │ Songhai                         │ son                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 210 │ Sesotho                                           │ Southern Sotho                  │ st                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 211 │ Español (Latinoamérica)                           │ Spanish (Latin American)        │ es-419              │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 212 │ ᮘᮞ ᮞᮥᮔ᮪ᮓ , Basa Sunda                               │ Sundanese                       │ su                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 213 │ siSwati                                           │ Swati                           │ ss                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 214 │ Reo Tahiti                                        │ Tahitian                        │ ty                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 215 │ тоҷикӣ                                            │ Tajik                           │ tg                  │ Cyrl      │ Cyrillic model  │ Mapped    │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 216 │ татар теле                                        │ Tatar                           │ tt                  │ Cyrl/Latn │ Cyrillic model  │ Mapped    │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 217 │ KʌThemnɛ                                          │ Temne                           │ tem                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 218 │ lea faka-Tonga                                    │ Tongan                          │ to                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 219 │ Xitsonga                                          │ Tsonga                          │ ts                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 220 │ Setswana                                          │ Tswana                          │ tn                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 221 │ Türkmençe                                         │ Turkmen                         │ tk                  │ Latn      │ Cyrillic model  │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 222 │ удмурт кыл                                        │ Udmurt                          │ udm                 │ Cyrl      │ Cyrillic model  │ Mapped    │ Experimental    │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 223 │ Tshivenḓa                                         │ Venda                           │ ve                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 224 │ Vod                                               │ Votic                           │ vot                 │ Cyrl/Latn │ Cyrillic model  │ Mapped    │                 │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 225 │ Frysk                                             │ Western Frisian                 │ fy                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 226 │ Wolof                                             │ Wolof                           │ wo                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 227 │ isiXhosa                                          │ Xhosa                           │ xh                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 228 │ Èdè Yorùbá                                        │ Yoruba                          │ yo                  │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ├─────┼───────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────┼───────────┼─────────────────┼───────────┼─────────────────┤
# │ 229 │ Diidxazá                                          │ Zapotec                         │ zap                 │ Latn      │ Latin model     │ Mapped    │ Supported       │
# ╘═════╧═══════════════════════════════════════════════════╧═════════════════════════════════╧═════════════════════╧═══════════╧═════════════════╧═══════════╧═════════════════╛

# %%
# Sort the merged table by the 'Language (English name)' column
sorted_table = merged_table.sort_values(by='languageHintscode', ascending=True)

# Save the sorted table to a CSV file
output_filename = "sorted_merged_table.csv"
sorted_table.to_csv(output_filename, index=False)

# Print confirmation message
print(f"The sorted table has been saved to '{output_filename}'.")
# Out:
# The sorted table has been saved to 'sorted_merged_table.csv'.

# %%
import json

# Initialize the base structure for the JSON
google_json = {}

# Iterate through the merged table to build the JSON structure
for index, row in sorted_table.iterrows():
    language_hint = row['languageHintscode']
    language = row['Language']
    language_name = row['Language (English name)']
    script = row['Script']
    mapping = row.get('Mapping', '')  # Assuming 'Mapping' is the column for Mapped status
    support_level = row['Support Level']

    # Start with the basic title format
    title = f"{language_name} / {language} / {script}"

    # Add / Mapped if the Mapping field is not empty
    if mapping:
        title += " / Mapped"
    
    # Add / Supports handwriting if the Support Level is 'Experimental' or 'Supported'
    if support_level in ['Experimental', 'Supported']:
        title += " / Supports handwriting"
    
    # Add this information to the google_json structure
    google_json[language_hint] = {
        "languages": [language_hint],
        "title": title
    }

# Save the JSON to a file
output_json_filename = "google_languages.json"
with open(output_json_filename, 'w', encoding='utf-8') as json_file:
    json.dump({"google": google_json}, json_file, ensure_ascii=False, indent=4)

# Print confirmation message
print(f"JSON file has been created and saved as '{output_json_filename}'.")
# Out:
# JSON file has been created and saved as 'google_languages.json'.
